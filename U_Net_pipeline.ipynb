# %% [markdown]
# ### Imports

# %%
# install requirements
# !pip install torchvision>=0.3.0
# !pip install pretrainedmodels==0.7.4
# !pip install segmentation_models_pytorch
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting pretrainedmodels==0.7.4
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 3.1MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4) (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4) (0.5.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4) (4.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels==0.7.4) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels==0.7.4) (1.12.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels==0.7.4) (6.2.2)
# Building wheels for collected packages: pretrainedmodels
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60962 sha256=9549bd70c06d5da3aa220eac4b8926e5daa1fce79bb47436f1ff03d35bbaf737
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# Installing collected packages: munch, pretrainedmodels
# Successfully installed munch-2.5.0 pretrainedmodels-0.7.4
# Collecting segmentation_models_pytorch
#   Downloading https://files.pythonhosted.org/packages/70/88/763a25dfe076a9f30f33466b1bd0f2d31b915b88d4cb4481fe4043cf26b4/segmentation_models_pytorch-0.1.0-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 2.6MB/s
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.6/dist-packages (from segmentation_models_pytorch) (0.7.4)
# Collecting efficientnet-pytorch>=0.5.1
#   Downloading https://files.pythonhosted.org/packages/e5/b7/c7cc9d8a95b7cfe4392c28fd5ff1854061aa75e81acf8d7539adb7612f20/efficientnet_pytorch-0.6.1.tar.gz
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from segmentation_models_pytorch) (0.5.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.28.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (1.4.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation_models_pytorch) (6.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation_models_pytorch) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation_models_pytorch) (1.12.0)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.1-cp36-none-any.whl size=12410 sha256=89d4d9191645c4c1e5f75762d932a5890253723a79fe3961aa9da6c77033c525
#   Stored in directory: /root/.cache/pip/wheels/0f/b0/79/1663bc9714b5d88deba05e44f593ce50111bd69305a45df87a
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.1 segmentation-models-pytorch-0.1.0
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-nleegvhj
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-nleegvhj
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.4.1)
# Collecting imgaug<0.2.7,>=0.2.5
#   Downloading https://files.pythonhosted.org/packages/ad/2e/748dbb7bb52ec8667098bae9b585f448569ae520031932687761165419a2/imgaug-0.2.6.tar.gz (631kB)
#      |████████████████████████████████| 634kB 4.7MB/s
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.16.2)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (6.2.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.6)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (45.1.0)
# Building wheels for collected packages: albumentations, imgaug
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=64129 sha256=8108af0edd681a15d64112eba83f74ea6b04bcb707870b383eee05c59ee93ad7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ziewpvxw/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
#   Building wheel for imgaug (setup.py) ... done
#   Created wheel for imgaug: filename=imgaug-0.2.6-cp36-none-any.whl size=654020 sha256=cefb8fe10d309f4ea67c1a39732056c65e2b74402f104e632a7dd2325c60cb1d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ziewpvxw/wheels/97/ec/48/0d25896c417b715af6236dbcef8f0bed136a1a5e52972fc6d0
# Successfully built albumentations imgaug
# Installing collected packages: imgaug, albumentations
#   Found existing installation: imgaug 0.2.9
#     Uninstalling imgaug-0.2.9:
#       Successfully uninstalled imgaug-0.2.9
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# Successfully installed albumentations-0.4.4 imgaug-0.2.6

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import random
import shutil
import segmentation_models_pytorch as smp
import numpy as np
import matplotlib.pyplot as plt
import PIL
import cv2
import albumentations as albu
import torch
import torch.nn as nn
from PIL import Image, ImageDraw
from albumentations.pytorch import ToTensor
from segmentation_models_pytorch.encoders import get_preprocessing_fn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

# %% [markdown]
# ###Prepare data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# unzip the datasets
# !unzip /content/drive/My\ Drive/p\ ImageBlending\ -\ ресурсы/Window_view/datasets/insta_100_images_dataset.zip
# Out:
# Archive:  /content/drive/My Drive/p ImageBlending - ресурсы/Window_view/datasets/insta_100_images_dataset.zip
#    creating: insta_100_images_dataset/
#    creating: insta_100_images_dataset/images/
#   inflating: insta_100_images_dataset/images/2013-09-29 09.46.39 555409553222055833_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2013-12-23 08.27.40 616975728757237436_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2014-04-25 06.26.09 706061989668504925_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2015-01-16 18.46.54 899225162260011133_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2015-07-12 21.20.58 1027588007703343893_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2015-09-09 01.59.52 1069765378192446164_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2016-07-25 16.37.58 1302135572697942271_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2016-10-13 08.20.49 1359867407959406477_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2016-10-14 03.22.59 1360442284113673763_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2016-11-05 21.26.37 1376932761269400446_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2016-11-17 11.34.20 1385331961044057412_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2016-12-01 19.07.22 1395706837118130706_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2017-01-01 07.43.46 1417830823159499645_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2018-11-05 14.20.01 1905804329580022142_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2019-03-09 15.46.54 1995720245448535907_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2019-09-15 08.34.24 2133209951610849407_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2019-10-03 17.30.55 2146525954850467530_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/images/2019-11-17 22.46.37 2179299757336128369_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2019-12-17 08.55.41 2200624799826066359_window.jpg
#   inflating: insta_100_images_dataset/images/2019-12-17 08.55.41 2200624799842994688_window.jpg
#   inflating: insta_100_images_dataset/images/2019-12-17 08.55.41 2200624804221804803_window.jpg
#   inflating: insta_100_images_dataset/images/2020-01-07 21.50.22 2216235006960263036_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-09 16.48.40 2217532709986962124_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-10 16.26.12 2218246174921723949_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-11 20.59.26 2219108474255893225_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-12 16.11.15 2219688207547926962_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-13 15.05.07 2220379690051701877_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-14 09.15.22 2220928437732518687_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-14 15.32.42 2221118351219121787_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-15 02.23.36 2221445960865631617_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-15 20.43.22 2221999491594353558_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-17 09.02.47 2223096429153106326_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-19 03.24.01 2224375472603858350_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-20 18.12.40 2225547522035011885_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-21 07.25.50 2225946735553654242_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-21 13.05.49 2226117857595131566_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-21 17.17.44 2226244640055535000_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-21 20.11.23 2226332046798694657_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-24 08.07.50 2228142199891502996_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-01-25 00.38.34 2228640850810830728_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-25 18.12.11 2229171152310604151_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-26 05.41.39 2229518172548003461_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-26 08.31.41 2229603757850985280_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-27 15.51.11 2230549737667735259_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-28 02.10.59 2230861694012603043_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-28 11.40.33 2231148368732756428_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-29 14.33.54 2231960389351156051_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-29 21.45.09 2232177451019008287_frommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-01-30 15.18.23 2232707560192792824_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-31 11.00.08 2233302353409643722_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-01-31 19.37.11 2233562588759144940_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-01-31 19.42.47 2233565413288061026_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-02-01 02.23.16 2233766975490610757_frommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-01 02.23.16 2233766975499048482_frommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-01 15.14.30 2234155158929985773_frommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-01 15.40.44 2234168358856296528_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-01 17.59.08 2234238017128963012_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 01.01.43 2234450336444296012_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 13.58.22 2234841609483325468_windowviews.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 17.06.51 2234936479826852136_frommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 17.13.51 2234940005364931267_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 22.00.53 2235084469661251743_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-02 22.41.03 2235104686667262155_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 04.46.42 2235288724807996115_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 04.46.42 2235288724808028203_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 04.46.42 2235288727802766249_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 07.07.20 2235359503317843500_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 09.36.09 2235434409620587485_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 11.02.26 2235477836570010330_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 12.54.42 2235534339080699584_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 13.29.31 2235551870575583960_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 16.18.32 2235636928829846904_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 17.04.07 2235659873224226363_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 17.04.07 2235659873249367713_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 17.11.13 2235663453909690250_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 17.55.31 2235685747399520927_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 18.50.28 2235713405772468836_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 19.47.30 2235742107846733447_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 19.49.18 2235743012498111927_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 20.14.45 2235755826903983773_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 20.37.41 2235767373705625803_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-03 21.21.11 2235789261454322463_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 05.29.01 2236034793132668362_windowtreatments.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 05.43.14 2236041951962937521_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 06.02.37 2236051712679162163_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 06.48.00 2236074549128327422_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 06.49.14 2236075169802456193_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 06.49.14 2236075169844554695_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 06.55.57 2236078556054733869_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 08.10.39 2236116154677133962_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 08.29.55 2236125851464022296_windowseat.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 08.40.16 2236131056545493857_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 08.49.25 2236135659047613333_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 09.08.58 2236145499604760562_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 09.10.13 2236146134506981970_window.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 09.56.31 2236169439964250168_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 11.52.29 2236227801545977639_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 12.35.45 2236249580606034297_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 13.33.20 2236278559839191749_windowview.jpg
#   inflating: insta_100_images_dataset/images/2020-02-04 13.57.10 2236290557042750876_windowview.jpg
#    creating: insta_100_images_dataset/masks/
#   inflating: insta_100_images_dataset/masks/2013-09-29 09.46.39 555409553222055833_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2013-12-23 08.27.40 616975728757237436_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2014-04-25 06.26.09 706061989668504925_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2015-01-16 18.46.54 899225162260011133_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2015-07-12 21.20.58 1027588007703343893_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2015-09-09 01.59.52 1069765378192446164_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2016-07-25 16.37.58 1302135572697942271_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2016-10-13 08.20.49 1359867407959406477_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2016-10-14 03.22.59 1360442284113673763_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2016-11-05 21.26.37 1376932761269400446_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2016-11-17 11.34.20 1385331961044057412_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2016-12-01 19.07.22 1395706837118130706_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2017-01-01 07.43.46 1417830823159499645_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2018-11-05 14.20.01 1905804329580022142_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2019-03-09 15.46.54 1995720245448535907_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2019-09-15 08.34.24 2133209951610849407_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2019-10-03 17.30.55 2146525954850467530_lookingthroughwindow.jpg
#   inflating: insta_100_images_dataset/masks/2019-11-17 22.46.37 2179299757336128369_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2019-12-17 08.55.41 2200624799826066359_window.jpg
#   inflating: insta_100_images_dataset/masks/2019-12-17 08.55.41 2200624799842994688_window.jpg
#   inflating: insta_100_images_dataset/masks/2019-12-17 08.55.41 2200624804221804803_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-07 21.50.22 2216235006960263036_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-09 16.48.40 2217532709986962124_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-10 16.26.12 2218246174921723949_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-11 20.59.26 2219108474255893225_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-12 16.11.15 2219688207547926962_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-13 15.05.07 2220379690051701877_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-14 09.15.22 2220928437732518687_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-14 15.32.42 2221118351219121787_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-15 02.23.36 2221445960865631617_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-15 20.43.22 2221999491594353558_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-17 09.02.47 2223096429153106326_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-19 03.24.01 2224375472603858350_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-20 18.12.40 2225547522035011885_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-21 07.25.50 2225946735553654242_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-21 13.05.49 2226117857595131566_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-21 17.17.44 2226244640055535000_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-21 20.11.23 2226332046798694657_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-24 08.07.50 2228142199891502996_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-25 00.38.34 2228640850810830728_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-25 18.12.11 2229171152310604151_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-26 05.41.39 2229518172548003461_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-26 08.31.41 2229603757850985280_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-27 15.51.11 2230549737667735259_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-28 02.10.59 2230861694012603043_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-28 11.40.33 2231148368732756428_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-29 14.33.54 2231960389351156051_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-29 21.45.09 2232177451019008287_frommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-30 15.18.23 2232707560192792824_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-31 11.00.08 2233302353409643722_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-31 19.37.11 2233562588759144940_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-01-31 19.42.47 2233565413288061026_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-01 02.23.16 2233766975490610757_frommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-01 02.23.16 2233766975499048482_frommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-01 15.14.30 2234155158929985773_frommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-01 15.40.44 2234168358856296528_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-01 17.59.08 2234238017128963012_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 01.01.43 2234450336444296012_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 13.58.22 2234841609483325468_windowviews.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 17.06.51 2234936479826852136_frommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 17.13.51 2234940005364931267_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 22.00.53 2235084469661251743_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-02 22.41.03 2235104686667262155_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 04.46.42 2235288724807996115_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 04.46.42 2235288724808028203_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 04.46.42 2235288727802766249_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 07.07.20 2235359503317843500_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 09.36.09 2235434409620587485_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 11.02.26 2235477836570010330_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 12.54.42 2235534339080699584_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 13.29.31 2235551870575583960_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 16.18.32 2235636928829846904_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 17.04.07 2235659873224226363_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 17.04.07 2235659873249367713_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 17.11.13 2235663453909690250_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 17.55.31 2235685747399520927_viewfrommywindow.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 18.50.28 2235713405772468836_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 19.47.30 2235742107846733447_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 19.49.18 2235743012498111927_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 20.14.45 2235755826903983773_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 20.37.41 2235767373705625803_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-03 21.21.11 2235789261454322463_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 05.29.01 2236034793132668362_windowtreatments.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 05.43.14 2236041951962937521_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 06.02.37 2236051712679162163_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 06.48.00 2236074549128327422_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 06.49.14 2236075169802456193_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 06.49.14 2236075169844554695_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 06.55.57 2236078556054733869_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 08.10.39 2236116154677133962_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 08.29.55 2236125851464022296_windowseat.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 08.40.16 2236131056545493857_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 08.49.25 2236135659047613333_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 09.08.58 2236145499604760562_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 09.10.13 2236146134506981970_window.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 09.56.31 2236169439964250168_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 11.52.29 2236227801545977639_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 12.35.45 2236249580606034297_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 13.33.20 2236278559839191749_windowview.jpg
#   inflating: insta_100_images_dataset/masks/2020-02-04 13.57.10 2236290557042750876_windowview.jpg

# %%
# create common folder for dataset
# !mkdir /content/dataset/
# !mkdir /content/dataset/train
# !mkdir /content/dataset/val
# !mkdir /content/dataset/test
# !mkdir /content/dataset/train/images
# !mkdir /content/dataset/val/images
# !mkdir /content/dataset/test/images
# !mkdir /content/dataset/train/masks
# !mkdir /content/dataset/val/masks
# !mkdir /content/dataset/test/masks

# %%
# folder list
list_folders = [
                'insta_100_images_dataset'
                ]

# cycle by folders
for folder in list_folders:
  list_images = os.listdir(os.path.join('/content/', folder, 'images'))
  random.shuffle(list_images)
  length = len(list_images)
  train = list_images[:int(0.8 * length)]
  val   = list_images[int(0.8 * length):int(0.9 * length)]
  test  = list_images[int(0.9 * length):]  
  for im in train:
    shutil.copyfile(os.path.join('/content', folder, 'images', im), os.path.join('/content/dataset/train/images', folder+im))
    shutil.copyfile(os.path.join('/content', folder, 'masks', im), os.path.join('/content/dataset/train/masks', folder+im))
  for im in val:
    shutil.copyfile(os.path.join('/content', folder, 'images', im), os.path.join('/content/dataset/val/images', folder+im))
    shutil.copyfile(os.path.join('/content', folder, 'masks', im), os.path.join('/content/dataset/val/masks', folder+im))
  for im in test:
    shutil.copyfile(os.path.join('/content', folder, 'images', im), os.path.join('/content/dataset/test/images', folder+im))
    shutil.copyfile(os.path.join('/content', folder, 'masks', im), os.path.join('/content/dataset/test/masks', folder+im))

# %% [markdown]
# ### Define the model

# %%
def get_training_augmentation():
  train_transform = [
      albu.Resize(256, 256),
      albu.HorizontalFlip(p=0.5),

      # albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

      # albu.PadIfNeeded(min_height=320, min_width=320, always_apply=True, border_mode=0),
      # albu.RandomCrop(height=320, width=320, always_apply=True),

      # albu.IAAAdditiveGaussianNoise(p=0.2),
      # albu.IAAPerspective(p=0.5),

      # albu.OneOf(
      #     [
              # albu.CLAHE(p=1),
              # albu.RandomBrightness(p=1),
              # albu.RandomGamma(p=1),
      #     ],
      #     p=0.9,
      # ),

      # albu.OneOf(
      #     [
              # albu.IAASharpen(p=1),
              # albu.Blur(blur_limit=3, p=1),
              # albu.MotionBlur(blur_limit=3, p=1),
      #     ],
      #     p=0.9,
      # ),

      # albu.OneOf(
      #     [
              # albu.RandomContrast(p=1),
              # albu.HueSaturationValue(p=1),
          # ],
          # p=0.9,
      # ),
      albu.Normalize(),
  ]
  return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
          albu.Resize(256, 256),
          albu.Normalize()
          # albu.PadIfNeeded(384, 480)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %%
class Dataset(BaseDataset):
  def __init__(
      self, 
      images_dir, 
      masks_dir, 
      augmentation=None, 
      preprocessing=None,
  ):
    self.names = os.listdir(images_dir)
    self.images_paths = [os.path.join(images_dir, name) for name in self.names]
    self.masks_paths = [os.path.join(masks_dir, name) for name in self.names]
    self.augmentation = augmentation
    self.preprocessing = preprocessing
    
  def __getitem__(self, i):
      # read data
      image = cv2.imread(self.images_paths[i])
      image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      mask = cv2.imread(self.masks_paths[i], 0)
      # mask = mask.astype('float')
      mask = np.clip(mask,0,1)
      mask = np.expand_dims(mask, axis=2)

              
      # apply augmentations
      if self.augmentation:
          sample = self.augmentation(image=image, mask=mask)
          image, mask = sample['image'], sample['mask']
      
      # apply preprocessing
      if self.preprocessing:
          sample = self.preprocessing(image=image, mask=mask)
          image, mask = sample['image'], sample['mask']
          
      return image, mask
      
  def __len__(self):
      return len(self.names)

# %%
# Lets look at data we have
x_train_dir = '/content/dataset/train/images'
y_train_dir = '/content/dataset/train/masks'

x_valid_dir = '/content/dataset/val/images'
y_valid_dir = '/content/dataset/val/masks'

x_test_dir = '/content/dataset/test/images'
y_test_dir = '/content/dataset/test/masks'

dataset = Dataset(x_train_dir, y_train_dir, augmentation=get_training_augmentation())

# %%
h,w = 3,3

fig,ax = plt.subplots(h,w,figsize=(9,round((9/w)*h)))
for i in range(h*w):
  image, mask = dataset[i]
  ax[(i)%h][i//w].set_xticklabels([])
  ax[(i)%h][i//w].set_yticklabels([])
  ax[(i)%h][i//w].axis('off')
  mask = mask.squeeze()
  image[mask!=0] = (0,255,0)
  ax[(i)%h][i//w].imshow(image)
  
plt.subplots_adjust(wspace=0, hspace=0)
fig.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
ENCODER = 'resnet34'
ENCODER_WEIGHTS = 'imagenet'

# create segmentation model with pretrained encoder
model = smp.Unet(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=1,
    activation='sigmoid'
)
model.to(device)

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
)

valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
)

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False)

# %%
def f_score(pr, gt, beta=1, eps=1e-7, threshold=None, activation='sigmoid'):
    """
    Args:
        pr (torch.Tensor): A list of predicted elements
        gt (torch.Tensor):  A list of elements that are to be predicted
        beta (float): positive constant
        eps (float): epsilon to avoid zero division
        threshold: threshold for outputs binarization
    Returns:
        float: F score
    """

    if activation is None or activation == "none":
        activation_fn = lambda x: x
    elif activation == "sigmoid":
        activation_fn = torch.nn.Sigmoid()
    elif activation == "softmax2d":
        activation_fn = torch.nn.Softmax2d()
    else:
        raise NotImplementedError(
            "Activation implemented for sigmoid and softmax2d"
        )

    pr = activation_fn(pr)

    if threshold is not None:
        pr = (pr > threshold).float()


    tp = torch.sum(gt * pr)
    fp = torch.sum(pr) - tp
    fn = torch.sum(gt) - tp

    score = ((1 + beta ** 2) * tp + eps) \
            / ((1 + beta ** 2) * tp + beta ** 2 * fn + fp + eps)

    return score

class DiceLoss(nn.Module):
  __name__ = 'dice_loss'

  def __init__(self, eps=1e-7, activation='sigmoid'):
      super().__init__()
      self.activation = activation
      self.eps = eps

  def forward(self, y_pr, y_gt):
      return 1 - f_score(y_pr, y_gt, beta=1., eps=self.eps, threshold=None, activation=self.activation)


class BCEDiceLoss(DiceLoss):
  __name__ = 'bce_dice_loss'

  def __init__(self, eps=1e-7, activation='sigmoid'):
      super().__init__(eps, activation)
      self.bce = nn.BCEWithLogitsLoss(reduction='mean')

  def forward(self, y_pr, y_gt):
      dice = super().forward(y_pr, y_gt)
      bce = self.bce(y_pr, y_gt)
      return dice + bce

# %%
loss = BCEDiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0001),
])

# %%
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=device,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=device,
    verbose=True,
)

# %%
max_score = 0

for i in range(0, 40):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, './best_model.pth')
        print('Model saved!')
        
    if i == 25:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5!')
# Out:
# Epoch: 0
# train: 100%|██████████| 80/80 [00:04<00:00, 16.73it/s, bce_dice_loss - 1.266, iou_score - 0.4839]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.22it/s, bce_dice_loss - 1.265, iou_score - 0.06442]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 80/80 [00:04<00:00, 16.68it/s, bce_dice_loss - 1.184, iou_score - 0.635]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.73it/s, bce_dice_loss - 1.166, iou_score - 0.6045]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 80/80 [00:04<00:00, 16.62it/s, bce_dice_loss - 1.15, iou_score - 0.6889]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.32it/s, bce_dice_loss - 1.153, iou_score - 0.6284]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 80/80 [00:04<00:00, 16.23it/s, bce_dice_loss - 1.126, iou_score - 0.7385]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.20it/s, bce_dice_loss - 1.231, iou_score - 0.1734]
#
# Epoch: 4
# train: 100%|██████████| 80/80 [00:04<00:00, 16.45it/s, bce_dice_loss - 1.105, iou_score - 0.7846]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.58it/s, bce_dice_loss - 1.203, iou_score - 0.2964]
#
# Epoch: 5
# train: 100%|██████████| 80/80 [00:04<00:00, 16.98it/s, bce_dice_loss - 1.094, iou_score - 0.8034]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.79it/s, bce_dice_loss - 1.193, iou_score - 0.3888]
#
# Epoch: 6
# train: 100%|██████████| 80/80 [00:04<00:00, 16.38it/s, bce_dice_loss - 1.086, iou_score - 0.8067]
# valid: 100%|██████████| 10/10 [00:00<00:00, 29.79it/s, bce_dice_loss - 1.262, iou_score - 0.07981]
#
# Epoch: 7
# train: 100%|██████████| 80/80 [00:04<00:00, 17.41it/s, bce_dice_loss - 1.076, iou_score - 0.8354]
# valid: 100%|██████████| 10/10 [00:00<00:00, 35.54it/s, bce_dice_loss - 1.267, iou_score - 0.04439]
#
# Epoch: 8
# train: 100%|██████████| 80/80 [00:04<00:00, 16.62it/s, bce_dice_loss - 1.074, iou_score - 0.8245]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.86it/s, bce_dice_loss - 1.172, iou_score - 0.5497]
#
# Epoch: 9
# train: 100%|██████████| 80/80 [00:05<00:00, 15.88it/s, bce_dice_loss - 1.058, iou_score - 0.8825]
# valid: 100%|██████████| 10/10 [00:00<00:00, 35.53it/s, bce_dice_loss - 1.145, iou_score - 0.5246]
#
# Epoch: 10
# train: 100%|██████████| 80/80 [00:04<00:00, 16.45it/s, bce_dice_loss - 1.053, iou_score - 0.8935]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.39it/s, bce_dice_loss - 1.201, iou_score - 0.3244]
#
# Epoch: 11
# train: 100%|██████████| 80/80 [00:04<00:00, 16.93it/s, bce_dice_loss - 1.05, iou_score - 0.8964]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.88it/s, bce_dice_loss - 1.153, iou_score - 0.5256]
#
# Epoch: 12
# train: 100%|██████████| 80/80 [00:04<00:00, 17.61it/s, bce_dice_loss - 1.046, iou_score - 0.9055]
# valid: 100%|██████████| 10/10 [00:00<00:00, 35.19it/s, bce_dice_loss - 1.143, iou_score - 0.5463]
#
# Epoch: 13
# train: 100%|██████████| 80/80 [00:04<00:00, 17.51it/s, bce_dice_loss - 1.044, iou_score - 0.9066]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.36it/s, bce_dice_loss - 1.143, iou_score - 0.5943]
#
# Epoch: 14
# train: 100%|██████████| 80/80 [00:04<00:00, 17.03it/s, bce_dice_loss - 1.04, iou_score - 0.9225]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.72it/s, bce_dice_loss - 1.149, iou_score - 0.5355]
#
# Epoch: 15
# train: 100%|██████████| 80/80 [00:04<00:00, 16.63it/s, bce_dice_loss - 1.038, iou_score - 0.9261]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.86it/s, bce_dice_loss - 1.131, iou_score - 0.5607]
#
# Epoch: 16
# train: 100%|██████████| 80/80 [00:04<00:00, 16.66it/s, bce_dice_loss - 1.037, iou_score - 0.9288]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.66it/s, bce_dice_loss - 1.141, iou_score - 0.54]
#
# Epoch: 17
# train: 100%|██████████| 80/80 [00:04<00:00, 14.82it/s, bce_dice_loss - 1.035, iou_score - 0.9326]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.03it/s, bce_dice_loss - 1.132, iou_score - 0.5642]
#
# Epoch: 18
# train: 100%|██████████| 80/80 [00:05<00:00, 15.96it/s, bce_dice_loss - 1.034, iou_score - 0.9365]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.41it/s, bce_dice_loss - 1.092, iou_score - 0.7225]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 80/80 [00:05<00:00, 16.46it/s, bce_dice_loss - 1.033, iou_score - 0.9389]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.05it/s, bce_dice_loss - 1.2, iou_score - 0.3035]
#
# Epoch: 20
# train: 100%|██████████| 80/80 [00:04<00:00, 15.23it/s, bce_dice_loss - 1.032, iou_score - 0.9406]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.22it/s, bce_dice_loss - 1.095, iou_score - 0.7249]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 80/80 [00:05<00:00, 15.78it/s, bce_dice_loss - 1.03, iou_score - 0.9451]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.82it/s, bce_dice_loss - 1.093, iou_score - 0.7047]
#
# Epoch: 22
# train: 100%|██████████| 80/80 [00:04<00:00, 16.04it/s, bce_dice_loss - 1.03, iou_score - 0.9472]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.26it/s, bce_dice_loss - 1.101, iou_score - 0.6811]
#
# Epoch: 23
# train: 100%|██████████| 80/80 [00:05<00:00, 15.86it/s, bce_dice_loss - 1.028, iou_score - 0.951]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.54it/s, bce_dice_loss - 1.088, iou_score - 0.7424]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 80/80 [00:05<00:00, 16.54it/s, bce_dice_loss - 1.028, iou_score - 0.9528]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.15it/s, bce_dice_loss - 1.105, iou_score - 0.6504]
#
# Epoch: 25
# train: 100%|██████████| 80/80 [00:04<00:00, 16.61it/s, bce_dice_loss - 1.027, iou_score - 0.9519]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.55it/s, bce_dice_loss - 1.099, iou_score - 0.6875]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 80/80 [00:04<00:00, 15.81it/s, bce_dice_loss - 1.027, iou_score - 0.9543]
# valid: 100%|██████████| 10/10 [00:00<00:00, 31.36it/s, bce_dice_loss - 1.086, iou_score - 0.74]
#
# Epoch: 27
# train: 100%|██████████| 80/80 [00:04<00:00, 16.39it/s, bce_dice_loss - 1.026, iou_score - 0.9587]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.90it/s, bce_dice_loss - 1.089, iou_score - 0.7319]
#
# Epoch: 28
# train: 100%|██████████| 80/80 [00:04<00:00, 16.00it/s, bce_dice_loss - 1.026, iou_score - 0.9597]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.92it/s, bce_dice_loss - 1.097, iou_score - 0.6714]
#
# Epoch: 29
# train: 100%|██████████| 80/80 [00:04<00:00, 14.04it/s, bce_dice_loss - 1.025, iou_score - 0.9612]
# valid: 100%|██████████| 10/10 [00:00<00:00, 28.69it/s, bce_dice_loss - 1.084, iou_score - 0.7535]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 80/80 [00:04<00:00, 17.32it/s, bce_dice_loss - 1.025, iou_score - 0.9621]
# valid: 100%|██████████| 10/10 [00:00<00:00, 35.02it/s, bce_dice_loss - 1.085, iou_score - 0.7495]
#
# Epoch: 31
# train: 100%|██████████| 80/80 [00:04<00:00, 16.99it/s, bce_dice_loss - 1.025, iou_score - 0.9629]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.79it/s, bce_dice_loss - 1.096, iou_score - 0.6861]
#
# Epoch: 32
# train: 100%|██████████| 80/80 [00:05<00:00, 15.63it/s, bce_dice_loss - 1.024, iou_score - 0.9638]
# valid: 100%|██████████| 10/10 [00:00<00:00, 30.34it/s, bce_dice_loss - 1.086, iou_score - 0.7226]
#
# Epoch: 33
# train: 100%|██████████| 80/80 [00:04<00:00, 16.94it/s, bce_dice_loss - 1.025, iou_score - 0.9634]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.86it/s, bce_dice_loss - 1.086, iou_score - 0.7359]
#
# Epoch: 34
# train: 100%|██████████| 80/80 [00:04<00:00, 17.94it/s, bce_dice_loss - 1.024, iou_score - 0.9661]
# valid: 100%|██████████| 10/10 [00:00<00:00, 29.76it/s, bce_dice_loss - 1.098, iou_score - 0.6636]
#
# Epoch: 35
# train: 100%|██████████| 80/80 [00:04<00:00, 16.14it/s, bce_dice_loss - 1.024, iou_score - 0.9665]
# valid: 100%|██████████| 10/10 [00:00<00:00, 28.32it/s, bce_dice_loss - 1.082, iou_score - 0.7447]
#
# Epoch: 36
# train: 100%|██████████| 80/80 [00:04<00:00, 16.97it/s, bce_dice_loss - 1.024, iou_score - 0.9662]
# valid: 100%|██████████| 10/10 [00:00<00:00, 33.60it/s, bce_dice_loss - 1.092, iou_score - 0.7103]
#
# Epoch: 37
# train: 100%|██████████| 80/80 [00:04<00:00, 16.86it/s, bce_dice_loss - 1.024, iou_score - 0.967]
# valid: 100%|██████████| 10/10 [00:00<00:00, 35.05it/s, bce_dice_loss - 1.091, iou_score - 0.694]
#
# Epoch: 38
# train: 100%|██████████| 80/80 [00:04<00:00, 17.01it/s, bce_dice_loss - 1.023, iou_score - 0.968]
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.52it/s, bce_dice_loss - 1.082, iou_score - 0.7538]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 80/80 [00:04<00:00, 17.92it/s, bce_dice_loss - 1.023, iou_score - 0.9681]
# valid: 100%|██████████| 10/10 [00:00<00:00, 34.04it/s, bce_dice_loss - 1.086, iou_score - 0.7109]

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
)

test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# evaluate model on test set
test_epoch = smp.utils.train.ValidEpoch(
    model=model,
    loss=loss,
    metrics=metrics,
    device=device,
)

logs = test_epoch.run(test_loader)
# Out:
# valid: 100%|██████████| 10/10 [00:00<00:00, 32.05it/s, bce_dice_loss - 1.122, iou_score - 0.6146]

# %%
# test dataset without transformations for image visualization
test_dataset_vis = Dataset(
    x_test_dir, y_test_dir
)

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
for i in range(5):
    n = np.random.choice(len(test_dataset))
    
    image_vis = test_dataset_vis[n][0].astype('uint8')
    image, gt_mask = test_dataset[n]
    
    gt_mask = gt_mask.squeeze()
    
    x_tensor = torch.from_numpy(image).to(device).unsqueeze(0)
    mask = model.predict(x_tensor)
    mask = (mask.squeeze().cpu().numpy().round())

    visualize(
        image=image_vis, 
        ground_truth_mask=gt_mask, 
        predicted_mask=mask
    )
